# %%
# %pip install dotenv requests oauthlib requests_oauthlib

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OAUTH2_CLIENT_ID = os.environ["OAUTH2_CLIENT_ID"]
OAUTH2_CLIENT_SECRET = os.environ["OAUTH2_CLIENT_SECRET"]
OAUTH2_TOKEN_ENDPOINT = os.environ["OAUTH2_TOKEN_ENDPOINT"]
COPERNICUS_WMS_ENDPOINT = os.environ["COPERNICUS_WMS_ENDPOINT"]

os.chdir("/home/me/workspace/det_remota/trabalho_final")

# %%
from oauthlib.oauth2 import BackendApplicationClient
from requests_oauthlib import OAuth2Session

# Create a session
client = BackendApplicationClient(client_id=OAUTH2_CLIENT_ID)
oauth = OAuth2Session(client=client)

# Get token for the session
OAUTH_TOKEN = ""
def refresh_token(): 
    global OAUTH_TOKEN
    OAUTH_TOKEN = oauth.fetch_token(
        token_url=OAUTH2_TOKEN_ENDPOINT,
        client_secret=OAUTH2_CLIENT_SECRET,
        include_client_id=True
    )
refresh_token()


# All requests using this session will have an access token automatically added
resp = oauth.get("https://sh.dataspace.copernicus.eu/configuration/v1/wms/instances")
resp.json()
# Out:
# [{'@id': 'https://sh.dataspace.copernicus.eu/configuration/v1/wms/instances/6aab06db-528b-441e-a958-9743a3ed06a3',
#   'id': '6aab06db-528b-441e-a958-9743a3ed06a3',
#   'name': 'Sentinel-2 L2A',
#   'domainAccountId': '17b3c6c5-72c3-4c63-aa70-4ad5dd877c6f',
#   'additionalData': {'showWarnings': True,
#    'showLogo': True,
#    'imageQuality': 90},
#   'created': '2025-04-11T23:21:35.358583Z',
#   'lastUpdated': '2025-04-11T23:22:17.001865Z',
#   'layers': {'@id': 'https://sh.dataspace.copernicus.eu/configuration/v1/wms/instances/6aab06db-528b-441e-a958-9743a3ed06a3/layers'}}]

# %%
from typing import Literal
import datetime

GET_MAP = "GetMap"
GET_CAPABILITIES = "GetCapabilities"

def wms_request(request: Literal["GetMap", "GetCapabilities"], params: dict = dict()):

    token_expires_at = datetime.datetime.fromtimestamp(OAUTH_TOKEN['expires_at'])
    cur_time = datetime.datetime.now()
    if token_expires_at < cur_time:
        print(f"Current time is {cur_time} and token expired at {token_expires_at}")
        print("Refreshing token")
        refresh_token()

    return oauth.get(COPERNICUS_WMS_ENDPOINT, params=dict(
        SERVICE="WMS",
        VERSION="1.3.0",
        REQUEST=request,
        **params
    ))

def get_capabilities():
    return wms_request(GET_CAPABILITIES).text

print(get_capabilities())
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <WMS_Capabilities version="1.3.0" xsi:schemaLocation="https:/inspire.ec.europa.eu/schemas/inspire_vs/1.0 https://inspire.ec.europa.eu/schemas/inspire_vs/1.0/inspire_vs.xsd" xmlns:inspire_common="https://inspire.ec.europa.eu/schemas/common/1.0" xmlns:inspire_vs="https://inspire.ec.europa.eu/schemas/inspire_vs/1.0" xmlns="http://www.opengis.net/wms" xmlns:sld="http://www.opengis.net/sld" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">	<Service>
# 		<Name>WMS</Name>
# 		<Title>Sentinel Hub WMS service - Sentinel-2 L2A</Title>
# 		<Abstract>
# <![CDATA[The Copernicus project's Sentinel satellites are revolutionizing earth observation (EO). Its free, full and open access to data with very short revisit times, high spatial resolution, and good spectral resolution are crucial for many applications. The portfolio of possible products is vast - use-cases of such a service range from plant health monitoring, land and water body change, flood monitoring, disaster mapping and more.However the current gap between Sentinel source data and its end-users is large: ESA's complex Scientific Data Hub raster files are compressed with JPEG2000 (13 raster filesfor each product, one per spectral band) terabytes of data per week additional processing requirementsTackling the data in an old-fashioned way - offering individual derivative products simply does not work anymore, the associated time and costs are large and defeat most of the major benefits of the Sentinel project. Our approach combines cloud-based GIS technologies, parallel processing and fully automated procedures. To support the fast developing EO field we provide tools directly to end-users. on-the-fly processing and visualization make it possible to build new products (e.g. vegetation indices and similar) in a matter of minutes.]]>		</Abstract>
# <OnlineResource xmlns:xlink="http://www.w3.org/1999/xlink" xlink:href="https://www.sentinel-hub.com" />
# <ContactInformation>
#   <ContactAddress>
#     <AddressType>postal</AddressType>
#     <Address>Cvetkova ulica 29</Address>
#     <City>Ljubljana</City>
#     <StateOrProvince/>
#     <PostCode>1000</PostCode>
#     <Country>Slovenia</Country>
#   </ContactAddress>
#   <ContactVoiceTelephone>+386 1 320-61-50</ContactVoiceTelephone>
#   <ContactFacsimileTelephone>+386 1 620-22-28</ContactFacsimileTelephone>
#   <ContactElectronicMailAddress>info@sinergise.com</ContactElectronicMailAddress>
# </ContactInformation>
# <Fees>https://www.sentinel-hub.com</Fees>     <AccessConstraints>
#      None
#      </AccessConstraints>
#      <Keyword>
#      humanGeographicViewer,thematicMultibandImageManipulationService,thematicProcessingService
#      </Keyword>
# 	</Service>
# 	<Capability>
# 		<Request>
# 			<GetCapabilities>
# 				<Format>application/xml</Format>
# 				<Format>text/xml</Format>
# 				<Format>application/vnd.ogc.wms_xml</Format>
# <DCPType>
# 	<HTTP>
# 		<Get>
# 			<OnlineResource xlink:href="https://sh.dataspace.copernicus.eu/ogc/wms/6aab06db-528b-441e-a958-9743a3ed06a3?" />
# 		</Get>
# 	</HTTP>
# </DCPType>
# 			</GetCapabilities>
# 			<GetMap>
# 				<Format>image/png</Format>
# 				<Format>image/jpeg</Format>
# 				<Format>image/jpg</Format>
# 				<Format>image/tiff</Format>
# 				<Format>application/vnd.google-earth.kmz+xml</Format>
# 				<Format>image/tiff;depth=8</Format>
# 				<Format>image/tiff;depth=16</Format>
# 				<Format>image/tiff;depth=32f</Format>
# 				<Format>application/vnd.google-earth.kmz+xml;image_type=image/jpeg</Format>
# 				<Format>application/vnd.google-earth.kmz+xml;image_type=image/png</Format>
# 				<Format>application/x-esri-shape</Format>
# 				<Format>application/json</Format>
# <DCPType>
# 	<HTTP>
# 		<Get>
# 			<OnlineResource xlink:href="https://sh.dataspace.copernicus.eu/ogc/wms/6aab06db-528b-441e-a958-9743a3ed06a3?" />
# 		</Get>
# 	</HTTP>
# </DCPType>
# 			</GetMap>
# 			<GetFeatureInfo>
# 				<Format>application/xml</Format>
# 				<Format>text/xml</Format>
# 				<Format>application/vnd.ogc.wms_xml</Format>
# 				<Format>application/vnd.ogc.gml</Format>
# 				<Format>text/html</Format>
# 				<Format>application/json</Format>
# 				<Format>text/plain</Format>
# <DCPType>
# 	<HTTP>
# 		<Get>
# 			<OnlineResource xlink:href="https://sh.dataspace.copernicus.eu/ogc/wms/6aab06db-528b-441e-a958-9743a3ed06a3?" />
# 		</Get>
# 	</HTTP>
# </DCPType>
# 			</GetFeatureInfo>
# 		</Request>
# 		<Exception>
# 			<Format>XML</Format>
# 		</Exception>
#         <inspire_vs:ExtendedCapabilities>
#             <inspire_common:ResourceLocator>
#                 <inspire_common:URL>https://sh.dataspace.copernicus.eu/ogc/wms/6aab06db-528b-441e-a958-9743a3ed06a3?REQUEST=GetCapabilities</inspire_common:URL>
#                 <inspire_common:MediaType>text/xml</inspire_common:MediaType>
#             </inspire_common:ResourceLocator>
#             <inspire_common:ResourceType>service</inspire_common:ResourceType>
#             <inspire_common:TemporalReference>
#                 <inspire_common:DateOfPublication>2015-11-30</inspire_common:DateOfPublication>
#             </inspire_common:TemporalReference>
#             <inspire_common:Conformity>
#                 <inspire_common:Specification>
#                     <inspire_common:Title>COMMISSION REGULATION (EU) No 1089/2010 of 23 November 2010 implementing Directive 2007/2/EC of the European Parliament and of the Council as regards interoperability of spatial data sets and services</inspire_common:Title>
#                     <inspire_common:DateOfPublication>2010-12-08</inspire_common:DateOfPublication>
#                     <inspire_common:URI>OJ:L:2010:323:0011:0102:EN:PDF</inspire_common:URI>
#                     <inspire_common:ResourceLocator>
#                         <inspire_common:URL>https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=OJ:L:2010:323:0011:0102:EN:PDF</inspire_common:URL>
#                         <inspire_common:MediaType>application/pdf</inspire_common:MediaType>
#                     </inspire_common:ResourceLocator>
#                 </inspire_common:Specification>
#                 <inspire_common:Degree>notEvaluated</inspire_common:Degree>
#             </inspire_common:Conformity>
#             <inspire_common:MetadataPointOfContact>
# <inspire_common:OrganisationName>Sinergise d.o.o.</inspire_common:OrganisationName>
# <inspire_common:EmailAddress>info@sentinel-hub.com</inspire_common:EmailAddress>            </inspire_common:MetadataPointOfContact>
#             <inspire_common:MetadataDate>2015-11-30</inspire_common:MetadataDate>
#             <inspire_common:SpatialDataServiceType>view</inspire_common:SpatialDataServiceType>
#             <inspire_common:MandatoryKeyword>
#                 <inspire_common:KeywordValue>infoMapAccessService</inspire_common:KeywordValue>
#             </inspire_common:MandatoryKeyword>
#             <inspire_common:SupportedLanguages>
#                 <inspire_common:DefaultLanguage>
#                     <inspire_common:Language>eng</inspire_common:Language>
#                 </inspire_common:DefaultLanguage>
#             </inspire_common:SupportedLanguages>
#             <inspire_common:ResponseLanguage>
#                 <inspire_common:Language>eng</inspire_common:Language>
#             </inspire_common:ResponseLanguage>
#         </inspire_vs:ExtendedCapabilities>
# 		<Layer>
# 			<Title>Sentinel Hub WMS</Title>
# 			<Abstract>WMS layer</Abstract>
# 			<CRS>EPSG:3857</CRS>
# 			<CRS>CRS:84</CRS>
# 			<CRS>EPSG:4326</CRS>
# 			<CRS>EPSG:3035</CRS>
# 			<CRS>EPSG:27700</CRS>
# 			<CRS>EPSG:2157</CRS>
# 			<CRS>EPSG:2154</CRS>
# 			<CRS>EPSG:3912</CRS>
# 			<CRS>EPSG:3794</CRS>
# 			<CRS>EPSG:5514</CRS>
# 			<CRS>EPSG:3765</CRS>
# 			<CRS>EPSG:4026</CRS>
# 			<CRS>SR-ORG:98739</CRS>
# 			<CRS>EPSG:28992</CRS>
# 			<CRS>EPSG:3003</CRS>
# 			<CRS>EPSG:3004</CRS>
# 			<CRS>EPSG:3844</CRS>
# 			<CRS>EPSG:3346</CRS>
# 			<CRS>EPSG:3301</CRS>
# 			<CRS>EPSG:2180</CRS>
# 			<CRS>EPSG:31287</CRS>
# 			<CRS>EPSG:3416</CRS>
# 			<CRS>EPSG:2193</CRS>
# 			<CRS>EPSG:3006</CRS>
# 			<CRS>EPSG:3005</CRS>
# 			<CRS>EPSG:3578</CRS>
# 			<CRS>EPSG:3161</CRS>
# 			<CRS>EPSG:3580</CRS>
# 			<CRS>EPSG:32184</CRS>
# 			<CRS>EPSG:3413</CRS>
# 			<CRS>EPSG:3995</CRS>
# 			<CRS>EPSG:3031</CRS>
# 			<CRS>EPSG:32601</CRS>
# 			<CRS>EPSG:32701</CRS>
# 			<CRS>EPSG:32602</CRS>
# 			<CRS>EPSG:32702</CRS>
# 			<CRS>EPSG:32603</CRS>
# 			<CRS>EPSG:32703</CRS>
# 			<CRS>EPSG:32604</CRS>
# 			<CRS>EPSG:32704</CRS>
# 			<CRS>EPSG:32605</CRS>
# 			<CRS>EPSG:32705</CRS>
# 			<CRS>EPSG:32606</CRS>
# 			<CRS>EPSG:32706</CRS>
# 			<CRS>EPSG:32607</CRS>
# 			<CRS>EPSG:32707</CRS>
# 			<CRS>EPSG:32608</CRS>
# 			<CRS>EPSG:32708</CRS>
# 			<CRS>EPSG:32609</CRS>
# 			<CRS>EPSG:32709</CRS>
# 			<CRS>EPSG:32610</CRS>
# 			<CRS>EPSG:32710</CRS>
# 			<CRS>EPSG:32611</CRS>
# 			<CRS>EPSG:32711</CRS>
# 			<CRS>EPSG:32612</CRS>
# 			<CRS>EPSG:32712</CRS>
# 			<CRS>EPSG:32613</CRS>
# 			<CRS>EPSG:32713</CRS>
# 			<CRS>EPSG:32614</CRS>
# 			<CRS>EPSG:32714</CRS>
# 			<CRS>EPSG:32615</CRS>
# 			<CRS>EPSG:32715</CRS>
# 			<CRS>EPSG:32616</CRS>
# 			<CRS>EPSG:32716</CRS>
# 			<CRS>EPSG:32617</CRS>
# 			<CRS>EPSG:32717</CRS>
# 			<CRS>EPSG:32618</CRS>
# 			<CRS>EPSG:32718</CRS>
# 			<CRS>EPSG:32619</CRS>
# 			<CRS>EPSG:32719</CRS>
# 			<CRS>EPSG:32620</CRS>
# 			<CRS>EPSG:32720</CRS>
# 			<CRS>EPSG:32621</CRS>
# 			<CRS>EPSG:32721</CRS>
# 			<CRS>EPSG:32622</CRS>
# 			<CRS>EPSG:32722</CRS>
# 			<CRS>EPSG:32623</CRS>
# 			<CRS>EPSG:32723</CRS>
# 			<CRS>EPSG:32624</CRS>
# 			<CRS>EPSG:32724</CRS>
# 			<CRS>EPSG:32625</CRS>
# 			<CRS>EPSG:32725</CRS>
# 			<CRS>EPSG:32626</CRS>
# 			<CRS>EPSG:32726</CRS>
# 			<CRS>EPSG:32627</CRS>
# 			<CRS>EPSG:32727</CRS>
# 			<CRS>EPSG:32628</CRS>
# 			<CRS>EPSG:32728</CRS>
# 			<CRS>EPSG:32629</CRS>
# 			<CRS>EPSG:32729</CRS>
# 			<CRS>EPSG:32630</CRS>
# 			<CRS>EPSG:32730</CRS>
# 			<CRS>EPSG:32631</CRS>
# 			<CRS>EPSG:32731</CRS>
# 			<CRS>EPSG:32632</CRS>
# 			<CRS>EPSG:32732</CRS>
# 			<CRS>EPSG:32633</CRS>
# 			<CRS>EPSG:32733</CRS>
# 			<CRS>EPSG:32634</CRS>
# 			<CRS>EPSG:32734</CRS>
# 			<CRS>EPSG:32635</CRS>
# 			<CRS>EPSG:32735</CRS>
# 			<CRS>EPSG:32636</CRS>
# 			<CRS>EPSG:32736</CRS>
# 			<CRS>EPSG:32637</CRS>
# 			<CRS>EPSG:32737</CRS>
# 			<CRS>EPSG:32638</CRS>
# 			<CRS>EPSG:32738</CRS>
# 			<CRS>EPSG:32639</CRS>
# 			<CRS>EPSG:32739</CRS>
# 			<CRS>EPSG:32640</CRS>
# 			<CRS>EPSG:32740</CRS>
# 			<CRS>EPSG:32641</CRS>
# 			<CRS>EPSG:32741</CRS>
# 			<CRS>EPSG:32642</CRS>
# 			<CRS>EPSG:32742</CRS>
# 			<CRS>EPSG:32643</CRS>
# 			<CRS>EPSG:32743</CRS>
# 			<CRS>EPSG:32644</CRS>
# 			<CRS>EPSG:32744</CRS>
# 			<CRS>EPSG:32645</CRS>
# 			<CRS>EPSG:32745</CRS>
# 			<CRS>EPSG:32646</CRS>
# 			<CRS>EPSG:32746</CRS>
# 			<CRS>EPSG:32647</CRS>
# 			<CRS>EPSG:32747</CRS>
# 			<CRS>EPSG:32648</CRS>
# 			<CRS>EPSG:32748</CRS>
# 			<CRS>EPSG:32649</CRS>
# 			<CRS>EPSG:32749</CRS>
# 			<CRS>EPSG:32650</CRS>
# 			<CRS>EPSG:32750</CRS>
# 			<CRS>EPSG:32651</CRS>
# 			<CRS>EPSG:32751</CRS>
# 			<CRS>EPSG:32652</CRS>
# 			<CRS>EPSG:32752</CRS>
# 			<CRS>EPSG:32653</CRS>
# 			<CRS>EPSG:32753</CRS>
# 			<CRS>EPSG:32654</CRS>
# 			<CRS>EPSG:32754</CRS>
# 			<CRS>EPSG:32655</CRS>
# 			<CRS>EPSG:32755</CRS>
# 			<CRS>EPSG:32656</CRS>
# 			<CRS>EPSG:32756</CRS>
# 			<CRS>EPSG:32657</CRS>
# 			<CRS>EPSG:32757</CRS>
# 			<CRS>EPSG:32658</CRS>
# 			<CRS>EPSG:32758</CRS>
# 			<CRS>EPSG:32659</CRS>
# 			<CRS>EPSG:32759</CRS>
# 			<CRS>EPSG:32660</CRS>
# 			<CRS>EPSG:32760</CRS>
# 			<CRS>EPSG:25828</CRS>
# 			<CRS>EPSG:25829</CRS>
# 			<CRS>EPSG:25830</CRS>
# 			<CRS>EPSG:25831</CRS>
# 			<CRS>EPSG:25832</CRS>
# 			<CRS>EPSG:25833</CRS>
# 			<CRS>EPSG:25834</CRS>
# 			<CRS>EPSG:25835</CRS>
# 			<CRS>EPSG:25836</CRS>
# 			<CRS>EPSG:25837</CRS>
# 			<EX_GeographicBoundingBox>
# 				<westBoundLongitude>-180</westBoundLongitude>
# 				<eastBoundLongitude>180</eastBoundLongitude>
# 				<southBoundLatitude>-90</southBoundLatitude>
# 				<northBoundLatitude>90</northBoundLatitude>
# 			</EX_GeographicBoundingBox>
# 			<BoundingBox CRS="EPSG:3857" maxx="20037508.342789" maxy="20037508.342789" minx="-20037508.342789" miny="-20037508.342789"/>
# 			<BoundingBox CRS="CRS:84" maxx="180" maxy="90" minx="-180" miny="-90"/>
# 			<BoundingBox CRS="EPSG:4326" maxx="90" maxy="180" minx="-90" miny="-180"/>
# 			<BoundingBox CRS="EPSG:3035" maxx="6928130" maxy="7824930" minx="196460" miny="-146470"/>
# 			<BoundingBox CRS="EPSG:27700" maxx="760000" maxy="1280000" minx="-120000" miny="-20000"/>
# 			<BoundingBox CRS="EPSG:2157" maxx="785110" maxy="968020" minx="421840" miny="515250"/>
# 			<BoundingBox CRS="EPSG:2154" maxx="1320650" maxy="7235613" minx="-378306" miny="6005280"/>
# 			<BoundingBox CRS="EPSG:3912" maxx="650000" maxy="200000" minx="350000" miny="0"/>
# 			<BoundingBox CRS="EPSG:3794" maxx="650000" maxy="200000" minx="350000" miny="0"/>
# 			<BoundingBox CRS="EPSG:5514" maxx="-159500" maxy="-911100" minx="-951600" miny="-1353400"/>
# 			<BoundingBox CRS="EPSG:3765" maxx="800000" maxy="5200000" minx="200000" miny="4650000"/>
# 			<BoundingBox CRS="EPSG:4026" maxx="375300" maxy="335350" minx="33540" miny="61520"/>
# 			<BoundingBox CRS="SR-ORG:98739" maxx="650000" maxy="1250000" minx="150000" miny="510000"/>
# 			<BoundingBox CRS="EPSG:28992" maxx="284310" maxy="636990" minx="630" miny="306570"/>
# 			<BoundingBox CRS="EPSG:3003" maxx="1868700" maxy="5214300" minx="1226000" miny="4042800"/>
# 			<BoundingBox CRS="EPSG:3004" maxx="2885300" maxy="5224200" minx="2145300" miny="3846400"/>
# 			<BoundingBox CRS="EPSG:3844" maxx="771870" maxy="1018810" minx="215530" miny="116260"/>
# 			<BoundingBox CRS="EPSG:3346" maxx="6268600" maxy="685400" minx="5972400" miny="172700"/>
# 			<BoundingBox CRS="EPSG:3301" maxx="6659000" maxy="751600" minx="6375000" miny="282500"/>
# 			<BoundingBox CRS="EPSG:2180" maxx="908420" maxy="876510" minx="125800" miny="144600"/>
# 			<BoundingBox CRS="EPSG:31287" maxx="575906" maxy="694886" minx="277747" miny="107674"/>
# 			<BoundingBox CRS="EPSG:3416" maxx="575906" maxy="694886" minx="277747" miny="107674"/>
# 			<BoundingBox CRS="EPSG:2193" maxx="6227000" maxy="2120000" minx="4736000" miny="987000"/>
# 			<BoundingBox CRS="EPSG:3006" maxx="7700000" maxy="950000" minx="6100000" miny="150000"/>
# 			<BoundingBox CRS="EPSG:3005" maxx="1884000" maxy="1737000" minx="34000" miny="359000"/>
# 			<BoundingBox CRS="EPSG:3578" maxx="979000" maxy="1716000" minx="25000" miny="610000"/>
# 			<BoundingBox CRS="EPSG:3161" maxx="1819000" maxy="13412000" minx="82000" miny="11672000"/>
# 			<BoundingBox CRS="EPSG:3580" maxx="558000" maxy="10336000" minx="-1336000" miny="8119000"/>
# 			<BoundingBox CRS="EPSG:32184" maxx="419000" maxy="6535000" minx="191000" miny="5224000"/>
# 			<BoundingBox CRS="EPSG:3413" maxx="3323161" maxy="3323161" minx="-3323161" miny="-3323161"/>
# 			<BoundingBox CRS="EPSG:3995" maxx="3333135" maxy="3333135" minx="-3333135" miny="-3333135"/>
# 			<BoundingBox CRS="EPSG:3031" maxx="3333135" maxy="3333135" minx="-3333135" miny="-3333135"/>
# 			<BoundingBox CRS="EPSG:32601" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32701" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32602" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32702" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32603" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32703" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32604" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32704" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32605" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32705" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32606" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32706" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32607" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32707" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32608" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32708" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32609" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32709" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32610" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32710" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32611" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32711" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32612" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32712" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32613" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32713" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32614" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32714" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32615" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32715" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32616" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32716" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32617" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32717" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32618" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32718" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32619" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32719" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32620" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32720" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32621" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32721" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32622" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32722" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32623" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32723" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32624" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32724" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32625" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32725" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32626" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32726" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32627" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32727" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32628" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32728" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32629" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32729" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32630" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32730" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32631" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32731" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32632" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32732" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32633" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32733" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32634" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32734" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32635" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32735" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32636" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32736" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32637" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32737" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32638" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32738" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32639" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32739" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32640" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32740" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32641" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32741" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32642" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32742" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32643" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32743" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32644" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32744" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32645" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32745" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32646" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32746" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32647" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32747" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32648" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32748" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32649" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32749" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32650" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32750" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32651" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32751" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32652" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32752" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32653" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32753" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32654" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32754" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32655" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32755" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32656" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32756" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32657" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32757" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32658" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32758" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32659" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32759" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:32660" maxx="850000" maxy="9350000" minx="150000" miny="0"/>
# 			<BoundingBox CRS="EPSG:32760" maxx="850000" maxy="10000000" minx="150000" miny="1100000"/>
# 			<BoundingBox CRS="EPSG:25828" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25829" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25830" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25831" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25832" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25833" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25834" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25835" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25836" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<BoundingBox CRS="EPSG:25837" maxx="850000" maxy="9350000" minx="150000" miny="3700000"/>
# 			<Dimension name="time" units="ISO8601" />
#       <Extent name="time" default="2025-04-12">1984-03-01/2025-04-12/P1D</Extent>
# 			<Layer queryable="1">
# 				<Name>AGRICULTURE</Name>
# 				<Title>Agriculture</Title>
# 				<Abstract>Based on bands 11, 8A and 2</Abstract>
# 				<Style>
# 					<Name>VIZ</Name>
# 					<Title>VIZ</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>ATMOSPHERIC_PENETRATION</Name>
# 				<Title>Atmospheric penetration</Title>
# 				<Abstract>Based on bands 12,11,8A</Abstract>
# 				<Style>
# 					<Name>VIZ</Name>
# 					<Title>VIZ</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>BATHYMETRIC</Name>
# 				<Title>Bathymetric</Title>
# 				<Abstract>Based on bands 4,3,1</Abstract>
# 				<Style>
# 					<Name>RGB</Name>
# 					<Title>RGB</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>NORMALIZED</Name>
# 					<Title>NORMALIZED</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>REFLECTANCE</Name>
# 					<Title>REFLECTANCE</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>COLOR_INFRARED</Name>
# 				<Title>Color Infrared (vegetation)</Title>
# 				<Abstract>Based on bands 8,4,3</Abstract>
# 				<Style>
# 					<Name>RGB</Name>
# 					<Title>RGB</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>NORMALIZED</Name>
# 					<Title>NORMALIZED</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>REFLECTANCE</Name>
# 					<Title>REFLECTANCE</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>COLOR_INFRARED__URBAN_</Name>
# 				<Title>False color (urban)</Title>
# 				<Abstract>Based on bands 12,11,4</Abstract>
# 				<Style>
# 					<Name>VIZ</Name>
# 					<Title>VIZ</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>GEOLOGY</Name>
# 				<Title>Geology</Title>
# 				<Abstract>Based on bands 12,4,2</Abstract>
# 				<Style>
# 					<Name>VIZ</Name>
# 					<Title>VIZ</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>MOISTURE_INDEX</Name>
# 				<Title>Moisture Index</Title>
# 				<Abstract>Based on combination of bands (B8A - B11)/(B8A + B11)</Abstract>
# 				<Style>
# 					<Name>VIZ</Name>
# 					<Title>VIZ</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>SWIR</Name>
# 				<Title>SWIR</Title>
# 				<Abstract>Based on bands 12,11,4</Abstract>
# 				<Style>
# 					<Name>VIZ</Name>
# 					<Title>VIZ</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>TRUE_COLOR</Name>
# 				<Title>Natural color (true color)</Title>
# 				<Abstract>Based on bands 4,3,2</Abstract>
# 				<Style>
# 					<Name>RGB</Name>
# 					<Title>RGB</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>NORMALIZED</Name>
# 					<Title>NORMALIZED</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>REFLECTANCE</Name>
# 					<Title>REFLECTANCE</Title>
#
# 				</Style>
# 			</Layer>
# 			<Layer queryable="1">
# 				<Name>VEGETATION_INDEX</Name>
# 				<Title>Vegetation Index - NDVI</Title>
# 				<Abstract>Based on combination of bands (B8 - B4)/(B8 + B4)</Abstract>
# 				<Style>
# 					<Name>COLOR_MAP</Name>
# 					<Title>COLOR_MAP</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>BLUE_RED</Name>
# 					<Title>BLUE_RED</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>GRAYSCALE</Name>
# 					<Title>GRAYSCALE</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>GREEN_WHITE</Name>
# 					<Title>GREEN_WHITE</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>INDEX</Name>
# 					<Title>INDEX</Title>
#
# 				</Style>
# 				<Style>
# 					<Name>RED_TEMPERATURE</Name>
# 					<Title>RED_TEMPERATURE</Title>
#
# 				</Style>
# 			</Layer>
# 		</Layer>
# 	</Capability>
# </WMS_Capabilities>

# %% [markdown]
# ### GetMap Parameters
#
# |WMS parameter | Info|
# |---------------|---------|
# |BBOX | Specifies the bounding box of the requested image. Coordinates must be in the specified coordinate reference system. The four coordinates representing the top-left and bottom-right of the bounding box must be separated by commas. Required. Example: BBOX=-13152499,4038942,-13115771,4020692|
# |CRS | (when VERSION 1.3.0 or higher) the coordinate reference system in which the BBOX is specified and in which to return the image. Optional, default: "EPSG:3857". For a list of available CRSs see the GetCapabilities result.|
# |SRS | (when VERSION 1.1.1 or lower) the coordinate reference system in which the BBOX is specified and in which to return the image. Optional, default: "EPSG:3857". For a list of available CRSs see the GetCapabilities result.|
# |FORMAT | The returned image format. Optional, default: "image/png", other options: "image/jpeg", "image/tiff". Detailed information about supported values.|
# |WIDTH | Returned image width in pixels. Required, unless RESX is used. If WIDTH is used, HEIGHT is also required.|
# |HEIGHT | Returned image height in pixels. Required, unless RESY is used. If HEIGHT is used, WIDTH is also required.|
# |RESX | Returned horizontal image resolution in UTM units (if m is added, e.g. 10m, in metrical units). (optional instead of WIDTH). If used, RESY is also required.|
# |RESY | Returned vertical image resolution in UTM units (if m is added, e.g. 10m, in metrical units). (optional instead of HEIGHT). If used, RESX is also required.|
# |LAYERS | The preconfigured layer (image) to be returned. You must specify exactly one layer and optionally add additional overlays. Required. Example: LAYERS=TRUE_COLOR,OUTLINE|
# |EXCEPTIONS | The exception format. Optional, default: "XML". Supported values: "XML", "INIMAGE", "BLANK" (all three for version >= 1.3.0), "application/vnd.ogc.se_xml", "application/vnd.ogc.se_inimage", "application/vnd.ogc.se_blank" (all three for version < 1.3.0).|

# %%
# %conda install pillow
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import Optional
from io import BytesIO
from PIL import Image


TileFormat = Literal["image/png", "image/jpeg", "image/tiff"]
# Ariquemes bounding box
# MINX	MINY	MAXX	MAXY
# -7081948.111609276	-1151449.6232446095	-6948853.905027688	-1081511.717608428
# Exemplo de uma área com vários espelhos dagua
# -7002111.5,-1090829.0,-6986823.9,-1100888.0


STUDY_AREA_BBOX = "-7002111.5,-1090829.0,-6986823.9,-1100888.0"


def get_tile(
    bbox: str = STUDY_AREA_BBOX,
    from_time:Optional[datetime.date]=None,
    to_time:Optional[datetime.date]=None,
    layer:str="COLOR_INFRARED",
    format:TileFormat="image/tiff", 
    max_cc:float=10,
    crs: str = 'EPSG:3857'
):
    if not from_time or not to_time:
        to_time = datetime.date.today()
        from_time = to_time - datetime.timedelta(days=15)
    
    print(f"Downloading layer {layer} in the period from {from_time} to {to_time}")

    response = wms_request(GET_MAP, params=dict(
        TIME=f"{from_time.isoformat()}/{to_time.isoformat()}",
        LAYERS=layer,
        FORMAT=format,
        MAXCC=max_cc,
        BBOX=bbox,
        CRS=crs,
        RESX="20m",
        RESY="20m",
    ))

    if response.status_code == 200:
        return response.content
    
    raise ValueError(f"Request failed with status {response.status_code}: {response.text}")

example_png = get_tile(max_cc=50, format="image/png")
Image.open(BytesIO(example_png)).show()
# Out:
# Downloading layer COLOR_INFRARED in the period from 2025-03-28 to 2025-04-12

# %%
from pathlib import Path


SENTINEL2_OUT_PATH = Path("data/sentinel2")


def first_weeks_of_month(year:int, month:int):
    first_date = datetime.date(year=year, month=month, day=1)
    last_date = datetime.date(year=year, month=month, day=14)
    return first_date, last_date

def last_weeks_of_month(year:int, month:int):
    first_date = datetime.date(year=year, month=month, day=15)
    next_month = datetime.date(year=year, month=month, day=28) + datetime.timedelta(days=4)
    last_date = next_month - datetime.timedelta(days=next_month.day)
    return first_date, last_date


def download_images(from_year: int = 2016, to_year: int = 2016):
    """
    COLOR_INFRARED is RGB 8-4-3
    SWIR is RGB 12-11-4
    """
    for year in range(from_year, to_year+1):
        for month in range(1, 12):
            for from_date, to_date in [first_weeks_of_month(year, month), last_weeks_of_month(year, month)]:
                for layer in ['COLOR_INFRARED', 'SWIR']:
                    image_bytes = get_tile(
                        from_time=from_date,
                        to_time=to_date,
                        layer=layer,
                        max_cc=100,
                        format="image/tiff",
                    )
                    filename = f'{layer}_{from_date}_{to_date}.tiff'
                    out_file_path = SENTINEL2_OUT_PATH / filename
                    out_file_path.parent.mkdir(parents=True, exist_ok=True)
                    
                    with open(out_file_path, 'wb') as out_file:
                        out_file_path.write_bytes(image_bytes)


download_images(from_year=2016, to_year=2020)
# Out:
# Downloading layer COLOR_INFRARED in the period from 2016-01-01 to 2016-01-14
# Downloading layer SWIR in the period from 2016-01-01 to 2016-01-14
# Downloading layer COLOR_INFRARED in the period from 2016-01-15 to 2016-01-31
# Downloading layer SWIR in the period from 2016-01-15 to 2016-01-31
# Downloading layer COLOR_INFRARED in the period from 2016-02-01 to 2016-02-14
# Downloading layer SWIR in the period from 2016-02-01 to 2016-02-14
# Downloading layer COLOR_INFRARED in the period from 2016-02-15 to 2016-02-29
# Downloading layer SWIR in the period from 2016-02-15 to 2016-02-29
# Downloading layer COLOR_INFRARED in the period from 2016-03-01 to 2016-03-14
# Downloading layer SWIR in the period from 2016-03-01 to 2016-03-14
# Downloading layer COLOR_INFRARED in the period from 2016-03-15 to 2016-03-31
# Downloading layer SWIR in the period from 2016-03-15 to 2016-03-31
# Downloading layer COLOR_INFRARED in the period from 2016-04-01 to 2016-04-14
# Downloading layer SWIR in the period from 2016-04-01 to 2016-04-14
# Downloading layer COLOR_INFRARED in the period from 2016-04-15 to 2016-04-30
# Downloading layer SWIR in the period from 2016-04-15 to 2016-04-30
# Downloading layer COLOR_INFRARED in the period from 2016-05-01 to 2016-05-14
# Downloading layer SWIR in the period from 2016-05-01 to 2016-05-14
# Downloading layer COLOR_INFRARED in the period from 2016-05-15 to 2016-05-31
# Downloading layer SWIR in the period from 2016-05-15 to 2016-05-31
# Downloading layer COLOR_INFRARED in the period from 2016-06-01 to 2016-06-14
# Downloading layer SWIR in the period from 2016-06-01 to 2016-06-14
# Downloading layer COLOR_INFRARED in the period from 2016-06-15 to 2016-06-30
# Downloading layer SWIR in the period from 2016-06-15 to 2016-06-30
# Downloading layer COLOR_INFRARED in the period from 2016-07-01 to 2016-07-14
# Downloading layer SWIR in the period from 2016-07-01 to 2016-07-14
# Downloading layer COLOR_INFRARED in the period from 2016-07-15 to 2016-07-31
# Downloading layer SWIR in the period from 2016-07-15 to 2016-07-31
# Downloading layer COLOR_INFRARED in the period from 2016-08-01 to 2016-08-14
# Downloading layer SWIR in the period from 2016-08-01 to 2016-08-14
# Downloading layer COLOR_INFRARED in the period from 2016-08-15 to 2016-08-31
# Downloading layer SWIR in the period from 2016-08-15 to 2016-08-31
# Downloading layer COLOR_INFRARED in the period from 2016-09-01 to 2016-09-14
# Downloading layer SWIR in the period from 2016-09-01 to 2016-09-14
# Downloading layer COLOR_INFRARED in the period from 2016-09-15 to 2016-09-30
# Downloading layer SWIR in the period from 2016-09-15 to 2016-09-30
# Downloading layer COLOR_INFRARED in the period from 2016-10-01 to 2016-10-14
# Downloading layer SWIR in the period from 2016-10-01 to 2016-10-14
# Downloading layer COLOR_INFRARED in the period from 2016-10-15 to 2016-10-31
# Downloading layer SWIR in the period from 2016-10-15 to 2016-10-31
# Downloading layer COLOR_INFRARED in the period from 2016-11-01 to 2016-11-14
# Downloading layer SWIR in the period from 2016-11-01 to 2016-11-14
# Downloading layer COLOR_INFRARED in the period from 2016-11-15 to 2016-11-30
# Downloading layer SWIR in the period from 2016-11-15 to 2016-11-30
# Downloading layer COLOR_INFRARED in the period from 2017-01-01 to 2017-01-14
# Downloading layer SWIR in the period from 2017-01-01 to 2017-01-14
# Downloading layer COLOR_INFRARED in the period from 2017-01-15 to 2017-01-31
# Downloading layer SWIR in the period from 2017-01-15 to 2017-01-31
# Downloading layer COLOR_INFRARED in the period from 2017-02-01 to 2017-02-14
# Downloading layer SWIR in the period from 2017-02-01 to 2017-02-14
# Downloading layer COLOR_INFRARED in the period from 2017-02-15 to 2017-02-28
# Downloading layer SWIR in the period from 2017-02-15 to 2017-02-28
# Downloading layer COLOR_INFRARED in the period from 2017-03-01 to 2017-03-14
# Downloading layer SWIR in the period from 2017-03-01 to 2017-03-14
# Downloading layer COLOR_INFRARED in the period from 2017-03-15 to 2017-03-31
# Downloading layer SWIR in the period from 2017-03-15 to 2017-03-31
# Downloading layer COLOR_INFRARED in the period from 2017-04-01 to 2017-04-14
# Downloading layer SWIR in the period from 2017-04-01 to 2017-04-14
# Downloading layer COLOR_INFRARED in the period from 2017-04-15 to 2017-04-30
# Downloading layer SWIR in the period from 2017-04-15 to 2017-04-30
# Downloading layer COLOR_INFRARED in the period from 2017-05-01 to 2017-05-14
# Downloading layer SWIR in the period from 2017-05-01 to 2017-05-14
# Downloading layer COLOR_INFRARED in the period from 2017-05-15 to 2017-05-31
# Downloading layer SWIR in the period from 2017-05-15 to 2017-05-31
# Downloading layer COLOR_INFRARED in the period from 2017-06-01 to 2017-06-14
# Downloading layer SWIR in the period from 2017-06-01 to 2017-06-14
# Downloading layer COLOR_INFRARED in the period from 2017-06-15 to 2017-06-30
# Downloading layer SWIR in the period from 2017-06-15 to 2017-06-30
# Downloading layer COLOR_INFRARED in the period from 2017-07-01 to 2017-07-14
# Downloading layer SWIR in the period from 2017-07-01 to 2017-07-14
# Downloading layer COLOR_INFRARED in the period from 2017-07-15 to 2017-07-31
# Downloading layer SWIR in the period from 2017-07-15 to 2017-07-31
# Downloading layer COLOR_INFRARED in the period from 2017-08-01 to 2017-08-14
# Downloading layer SWIR in the period from 2017-08-01 to 2017-08-14
# Downloading layer COLOR_INFRARED in the period from 2017-08-15 to 2017-08-31
# Downloading layer SWIR in the period from 2017-08-15 to 2017-08-31
# Downloading layer COLOR_INFRARED in the period from 2017-09-01 to 2017-09-14
# Downloading layer SWIR in the period from 2017-09-01 to 2017-09-14
# Downloading layer COLOR_INFRARED in the period from 2017-09-15 to 2017-09-30
# Downloading layer SWIR in the period from 2017-09-15 to 2017-09-30
# Downloading layer COLOR_INFRARED in the period from 2017-10-01 to 2017-10-14
# Downloading layer SWIR in the period from 2017-10-01 to 2017-10-14
# Downloading layer COLOR_INFRARED in the period from 2017-10-15 to 2017-10-31
# Downloading layer SWIR in the period from 2017-10-15 to 2017-10-31
# Downloading layer COLOR_INFRARED in the period from 2017-11-01 to 2017-11-14
# Downloading layer SWIR in the period from 2017-11-01 to 2017-11-14
# Downloading layer COLOR_INFRARED in the period from 2017-11-15 to 2017-11-30
# Downloading layer SWIR in the period from 2017-11-15 to 2017-11-30
# Downloading layer COLOR_INFRARED in the period from 2018-01-01 to 2018-01-14
# Downloading layer SWIR in the period from 2018-01-01 to 2018-01-14
# Downloading layer COLOR_INFRARED in the period from 2018-01-15 to 2018-01-31
# Downloading layer SWIR in the period from 2018-01-15 to 2018-01-31
# Downloading layer COLOR_INFRARED in the period from 2018-02-01 to 2018-02-14
# Downloading layer SWIR in the period from 2018-02-01 to 2018-02-14
# Downloading layer COLOR_INFRARED in the period from 2018-02-15 to 2018-02-28
# Downloading layer SWIR in the period from 2018-02-15 to 2018-02-28
# Downloading layer COLOR_INFRARED in the period from 2018-03-01 to 2018-03-14
# Downloading layer SWIR in the period from 2018-03-01 to 2018-03-14
# Downloading layer COLOR_INFRARED in the period from 2018-03-15 to 2018-03-31
# Downloading layer SWIR in the period from 2018-03-15 to 2018-03-31
# Downloading layer COLOR_INFRARED in the period from 2018-04-01 to 2018-04-14
# Downloading layer SWIR in the period from 2018-04-01 to 2018-04-14
# Downloading layer COLOR_INFRARED in the period from 2018-04-15 to 2018-04-30
# Downloading layer SWIR in the period from 2018-04-15 to 2018-04-30
# Downloading layer COLOR_INFRARED in the period from 2018-05-01 to 2018-05-14
# Downloading layer SWIR in the period from 2018-05-01 to 2018-05-14
# Downloading layer COLOR_INFRARED in the period from 2018-05-15 to 2018-05-31
# Downloading layer SWIR in the period from 2018-05-15 to 2018-05-31
# Downloading layer COLOR_INFRARED in the period from 2018-06-01 to 2018-06-14
# Downloading layer SWIR in the period from 2018-06-01 to 2018-06-14
# Downloading layer COLOR_INFRARED in the period from 2018-06-15 to 2018-06-30
# Downloading layer SWIR in the period from 2018-06-15 to 2018-06-30
# Downloading layer COLOR_INFRARED in the period from 2018-07-01 to 2018-07-14
# Downloading layer SWIR in the period from 2018-07-01 to 2018-07-14
# Downloading layer COLOR_INFRARED in the period from 2018-07-15 to 2018-07-31
# Downloading layer SWIR in the period from 2018-07-15 to 2018-07-31
# Downloading layer COLOR_INFRARED in the period from 2018-08-01 to 2018-08-14
# Downloading layer SWIR in the period from 2018-08-01 to 2018-08-14
# Downloading layer COLOR_INFRARED in the period from 2018-08-15 to 2018-08-31
# Downloading layer SWIR in the period from 2018-08-15 to 2018-08-31
# Downloading layer COLOR_INFRARED in the period from 2018-09-01 to 2018-09-14
# Downloading layer SWIR in the period from 2018-09-01 to 2018-09-14
# Downloading layer COLOR_INFRARED in the period from 2018-09-15 to 2018-09-30
# Downloading layer SWIR in the period from 2018-09-15 to 2018-09-30
# Downloading layer COLOR_INFRARED in the period from 2018-10-01 to 2018-10-14
# Downloading layer SWIR in the period from 2018-10-01 to 2018-10-14
# Downloading layer COLOR_INFRARED in the period from 2018-10-15 to 2018-10-31
# Downloading layer SWIR in the period from 2018-10-15 to 2018-10-31
# Downloading layer COLOR_INFRARED in the period from 2018-11-01 to 2018-11-14
# Downloading layer SWIR in the period from 2018-11-01 to 2018-11-14
# Downloading layer COLOR_INFRARED in the period from 2018-11-15 to 2018-11-30
# Downloading layer SWIR in the period from 2018-11-15 to 2018-11-30
# Downloading layer COLOR_INFRARED in the period from 2019-01-01 to 2019-01-14
# Downloading layer SWIR in the period from 2019-01-01 to 2019-01-14
# Downloading layer COLOR_INFRARED in the period from 2019-01-15 to 2019-01-31
# Downloading layer SWIR in the period from 2019-01-15 to 2019-01-31
# Downloading layer COLOR_INFRARED in the period from 2019-02-01 to 2019-02-14
# Downloading layer SWIR in the period from 2019-02-01 to 2019-02-14
# Downloading layer COLOR_INFRARED in the period from 2019-02-15 to 2019-02-28
# Downloading layer SWIR in the period from 2019-02-15 to 2019-02-28
# Downloading layer COLOR_INFRARED in the period from 2019-03-01 to 2019-03-14
# Downloading layer SWIR in the period from 2019-03-01 to 2019-03-14
# Downloading layer COLOR_INFRARED in the period from 2019-03-15 to 2019-03-31
# Downloading layer SWIR in the period from 2019-03-15 to 2019-03-31
# Downloading layer COLOR_INFRARED in the period from 2019-04-01 to 2019-04-14
# Downloading layer SWIR in the period from 2019-04-01 to 2019-04-14
# Downloading layer COLOR_INFRARED in the period from 2019-04-15 to 2019-04-30
# Downloading layer SWIR in the period from 2019-04-15 to 2019-04-30
# Downloading layer COLOR_INFRARED in the period from 2019-05-01 to 2019-05-14
# Downloading layer SWIR in the period from 2019-05-01 to 2019-05-14
# Downloading layer COLOR_INFRARED in the period from 2019-05-15 to 2019-05-31
# Downloading layer SWIR in the period from 2019-05-15 to 2019-05-31
# Downloading layer COLOR_INFRARED in the period from 2019-06-01 to 2019-06-14
# Downloading layer SWIR in the period from 2019-06-01 to 2019-06-14
# Downloading layer COLOR_INFRARED in the period from 2019-06-15 to 2019-06-30
# Downloading layer SWIR in the period from 2019-06-15 to 2019-06-30
# Downloading layer COLOR_INFRARED in the period from 2019-07-01 to 2019-07-14
# Downloading layer SWIR in the period from 2019-07-01 to 2019-07-14
# Downloading layer COLOR_INFRARED in the period from 2019-07-15 to 2019-07-31
# Downloading layer SWIR in the period from 2019-07-15 to 2019-07-31
# Downloading layer COLOR_INFRARED in the period from 2019-08-01 to 2019-08-14
# Downloading layer SWIR in the period from 2019-08-01 to 2019-08-14
# Downloading layer COLOR_INFRARED in the period from 2019-08-15 to 2019-08-31
# Downloading layer SWIR in the period from 2019-08-15 to 2019-08-31
# Downloading layer COLOR_INFRARED in the period from 2019-09-01 to 2019-09-14
# Downloading layer SWIR in the period from 2019-09-01 to 2019-09-14
# Downloading layer COLOR_INFRARED in the period from 2019-09-15 to 2019-09-30
# Downloading layer SWIR in the period from 2019-09-15 to 2019-09-30
# Downloading layer COLOR_INFRARED in the period from 2019-10-01 to 2019-10-14
# Downloading layer SWIR in the period from 2019-10-01 to 2019-10-14
# Downloading layer COLOR_INFRARED in the period from 2019-10-15 to 2019-10-31
# Downloading layer SWIR in the period from 2019-10-15 to 2019-10-31
# Downloading layer COLOR_INFRARED in the period from 2019-11-01 to 2019-11-14
# Downloading layer SWIR in the period from 2019-11-01 to 2019-11-14
# Downloading layer COLOR_INFRARED in the period from 2019-11-15 to 2019-11-30
# Downloading layer SWIR in the period from 2019-11-15 to 2019-11-30
# Downloading layer COLOR_INFRARED in the period from 2020-01-01 to 2020-01-14
# Downloading layer SWIR in the period from 2020-01-01 to 2020-01-14
# Downloading layer COLOR_INFRARED in the period from 2020-01-15 to 2020-01-31
# Downloading layer SWIR in the period from 2020-01-15 to 2020-01-31
# Downloading layer COLOR_INFRARED in the period from 2020-02-01 to 2020-02-14
# Downloading layer SWIR in the period from 2020-02-01 to 2020-02-14
# Downloading layer COLOR_INFRARED in the period from 2020-02-15 to 2020-02-29
# Downloading layer SWIR in the period from 2020-02-15 to 2020-02-29
# Downloading layer COLOR_INFRARED in the period from 2020-03-01 to 2020-03-14
# Downloading layer SWIR in the period from 2020-03-01 to 2020-03-14
# Downloading layer COLOR_INFRARED in the period from 2020-03-15 to 2020-03-31
# Downloading layer SWIR in the period from 2020-03-15 to 2020-03-31
# Downloading layer COLOR_INFRARED in the period from 2020-04-01 to 2020-04-14
# Downloading layer SWIR in the period from 2020-04-01 to 2020-04-14
# Downloading layer COLOR_INFRARED in the period from 2020-04-15 to 2020-04-30
# Downloading layer SWIR in the period from 2020-04-15 to 2020-04-30
# Downloading layer COLOR_INFRARED in the period from 2020-05-01 to 2020-05-14
# Downloading layer SWIR in the period from 2020-05-01 to 2020-05-14
# Downloading layer COLOR_INFRARED in the period from 2020-05-15 to 2020-05-31
# Downloading layer SWIR in the period from 2020-05-15 to 2020-05-31
# Downloading layer COLOR_INFRARED in the period from 2020-06-01 to 2020-06-14
# Downloading layer SWIR in the period from 2020-06-01 to 2020-06-14
# Downloading layer COLOR_INFRARED in the period from 2020-06-15 to 2020-06-30
# Downloading layer SWIR in the period from 2020-06-15 to 2020-06-30
# Downloading layer COLOR_INFRARED in the period from 2020-07-01 to 2020-07-14
# Downloading layer SWIR in the period from 2020-07-01 to 2020-07-14
# Downloading layer COLOR_INFRARED in the period from 2020-07-15 to 2020-07-31
# Downloading layer SWIR in the period from 2020-07-15 to 2020-07-31
# Downloading layer COLOR_INFRARED in the period from 2020-08-01 to 2020-08-14
# Downloading layer SWIR in the period from 2020-08-01 to 2020-08-14
# Downloading layer COLOR_INFRARED in the period from 2020-08-15 to 2020-08-31
# Downloading layer SWIR in the period from 2020-08-15 to 2020-08-31
# Downloading layer COLOR_INFRARED in the period from 2020-09-01 to 2020-09-14
# Downloading layer SWIR in the period from 2020-09-01 to 2020-09-14
# Downloading layer COLOR_INFRARED in the period from 2020-09-15 to 2020-09-30
# Downloading layer SWIR in the period from 2020-09-15 to 2020-09-30
# Downloading layer COLOR_INFRARED in the period from 2020-10-01 to 2020-10-14
# Downloading layer SWIR in the period from 2020-10-01 to 2020-10-14
# Downloading layer COLOR_INFRARED in the period from 2020-10-15 to 2020-10-31
# Downloading layer SWIR in the period from 2020-10-15 to 2020-10-31
# Downloading layer COLOR_INFRARED in the period from 2020-11-01 to 2020-11-14
# Downloading layer SWIR in the period from 2020-11-01 to 2020-11-14
# Downloading layer COLOR_INFRARED in the period from 2020-11-15 to 2020-11-30
# Downloading layer SWIR in the period from 2020-11-15 to 2020-11-30
